# %% [markdown]
# <a href="https://colab.research.google.com/github/Damlagoleli/hu-bby162-2022-/blob/main/proje04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")

dosyaYolu = ("/content/drive/MyDrive/veritabanı.txt")

def kitap_ekle():
    baslik = input("Kitap Başlıği: ").strip().title()
    yazar = input("Kitap Yazarı: ").strip().title()
    yayinevi = input("Yayın Evi: ").strip().title()
    basimyili = input("Basım yılı : ").strip()
    
    
    with open("/content/drive/MyDrive/veritabanı.txt", "a",encoding = "UTF-8") as kitap_listesi:
     kitap_listesi.write(f"\n{baslik}|{yazar}|{basimyili}|{yayinevi}")

def kitap_bul():
    kitap_listesi = bütün_kitaplar()
    eslesen_kitaplar = []

    Arama = input("Aramak için bir kitap başlığı giriniz: ").strip().lower()

    for kitap in kitap_listesi:
      if Arama in kitap["Başlık"].lower():
        eslesen_kitaplar.append(kitap)
        

    return eslesen_kitaplar

def bütün_kitaplar():
  kitaplar = []
  with open("/content/drive/MyDrive/veritabanı.txt", "r",encoding = "UTF-8") as kitap_listesi:
    for kitap in kitap_listesi:
      baslik, yazar, basimyili, yayinevi = kitap.strip().split("|")

      kitaplar.append({
          "Başlık": baslik,
          "Yazar": yazar,
          "BasımYılı": basimyili,
          "YayınEvi": yayinevi
            })
                
  return kitaplar

def Kitap_göster(kitaplar):
    print()

    for kitap in kitaplar:
        print(f"{kitap['Başlık']}, {kitap['Yazar']}, {kitap['BasımYılı']}, ({kitap['YayınEvi']})")
     
    print()

menü = """Aşağıdaki seçeneklerden birini seçiniz:

- 'a' Kitap Ekle
- 'l' Kitapları Listele
- 's' Kitap Ara
- 'q' Çıkış

Ne yapmak istersiniz? """

secenek = input(menü).strip().lower()

while secenek != "q":
  if secenek == "a":
    kitap_ekle()
  elif secenek == "l":
    kitap_listesi = bütün_kitaplar()
    if kitap_listesi:
      Kitap_göster(kitap_listesi)
    else:
      print("Listeniz boş gözüküyor.")
  elif secenek == "s":
    eslesen_kitaplar = kitap_bul()
    if eslesen_kitaplar:
      Kitap_göster(eslesen_kitaplar)
    else:
      print("Üzgünüm aradığınız kitap bulunamadı.")
  else:
    print(f"Üzgünüm, '{secenek}' Geçerli bir seçenek değil.")
  secenek = input(menü).strip().lower()
# Out:
# Mounted at /content/drive
# Aşağıdaki seçeneklerden birini seçiniz:
#
# - 'a' Kitap Ekle
# - 'l' Kitapları Listele
# - 's' Kitap Ara
# - 'q' Çıkış
#
# Ne yapmak istersiniz? a
# Kitap Başlıği: ütopya
# Kitap Yazarı: thomas more
# Yayın Evi: salon yayınevi
# Basım yılı : 1516
# Aşağıdaki seçeneklerden birini seçiniz:
#
# - 'a' Kitap Ekle
# - 'l' Kitapları Listele
# - 's' Kitap Ara
# - 'q' Çıkış
#
# Ne yapmak istersiniz? l
#
# 1.Ben Kirke , Madeline Miller, 2019, ( İthaki Yayınları)
# 2.Martin Eden,  Jack London, 1909, (İş Bankası Kültür Yayınları)
# 3.Denemeler, Montaigne, 2006, (İş Bankası Kültür Yayınları)
# Ütopya, Thomas More, 1516, (Salon Yayınevi)
#
# Aşağıdaki seçeneklerden birini seçiniz:
#
# - 'a' Kitap Ekle
# - 'l' Kitapları Listele
# - 's' Kitap Ara
# - 'q' Çıkış
#
# Ne yapmak istersiniz? s
# Aramak için bir kitap başlığı giriniz: ben kirke
#
# 1.Ben Kirke , Madeline Miller, 2019, ( İthaki Yayınları)
#
# Aşağıdaki seçeneklerden birini seçiniz:
#
# - 'a' Kitap Ekle
# - 'l' Kitapları Listele
# - 's' Kitap Ara
# - 'q' Çıkış
#
# Ne yapmak istersiniz? q
